# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Banking.csv')

# %%
display(df.head())
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
print("\nDataFrame Info:")
display(df.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Client ID                     object
# Name                          object
# Age                            int64
# Location ID                    int64
# Joined Bank                   object
# Banking Contact               object
# Nationality                   object
# Occupation                    object
# Fee Structure                 object
# Loyalty Classification        object
# Estimated Income             float64
# Superannuation Savings       float64
# Amount of Credit Cards         int64
# Credit Card Balance          float64
# Bank Loans                   float64
# Bank Deposits                float64
# Checking Accounts            float64
# Saving Accounts              float64
# Foreign Currency Account     float64
# Business Lending             float64
# Properties Owned               int64
# Risk Weighting                 int64
# BRId                           int64
# GenderId                       int64
# IAId                           int64
# ...

# %%
display(df["Estimated Income"].sort_values(ascending=True))
# Out:
# 1704     15919.48
# 2713     16653.97
# 1811     17226.85
# 1113     17367.22
# 481      17723.13
#           ...
# 1476    514809.57
# 1017    520192.44
# 1093    520328.35
# 1189    521159.98
# 1279    522330.26
# Name: Estimated Income, Length: 3000, dtype: float64

# %%
## Creating income bands using custom bins
bins=[0, 100000, 300000 , float('inf')]
labels=['Low', 'Medium', 'High']

df["Income Band"]= pd.cut(df["Estimated Income"], bins=bins, labels=labels, include_lowest=True)

# %%
categorical_cols = df[["Risk Weighting","Nationality","Occupation","Fee Structure","Loyalty Classification","Properties Owned","Income Band"]].columns
for col in categorical_cols:
    print(f'Value counts for {col}:')
    display(df[col].value_counts())
# Out:
# Value counts for Risk Weighting:
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64
# Value counts for Nationality:
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# Value counts for Occupation:
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# Recruiter                       25
# Account Coordinator             24
# Human Resources Manager         24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# Name: count, Length: 195, dtype: int64
# Value counts for Fee Structure:
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: count, dtype: int64
# Value counts for Loyalty Classification:
# ...

# %%
print("\nStatistical summary")
display(df.describe()) ## Getting stastistical summary of numerical columns
# Out:
# Statistical summary
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
print("\nMissing values in each column:")
df.isnull().sum()
# Out:
# Missing values in each column:
# Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income Band                 0
# dtype: int64

# %%
df["Joined Bank"].head()
# Out:
# 0    06-05-2019
# 1    10-12-2001
# 2    25-01-2010
# 3    28-03-2019
# 4    20-07-2012
# Name: Joined Bank, dtype: object

# %%
df["Joined Bank"]= pd.to_datetime(df["Joined Bank"], format="%d-%m-%Y")

# %%
numerical_cols = ['Fee Structure','Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans',
                   'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']
## Visualizing distribution of numerical columns
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(4, 3, i + 1)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
numerical_cols = ['Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
                  'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
                  'Foreign Currency Account', 'Business Lending', 'Properties Owned']


correlation_matrix = df[numerical_cols].corr()

## Visualizing the correlatin matrix using heatmap
plt.figure(figsize=(12, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
pairs_to_plot = [
    ('Bank Deposits', 'Saving Accounts'),
    ('Checking Accounts', 'Saving Accounts'),
    ('Checking Accounts', 'Foreign Currency Account'),
    ('Age', 'Superannuation Savings'),
    ('Estimated Income', 'Checking Accounts'),
    ('Bank Loans', 'Credit Card Balance'),
    ('Business Lending', 'Bank Loans'),
]


for x_col, y_col in pairs_to_plot:
    plt.figure(figsize=(8, 6))
    sns.regplot(
        data=df,
        x=x_col,
        y=y_col,
        scatter_kws={'alpha': 0.4},   ## Making points semi_transparent  
        line_kws={'color': 'red'}     ## best fit line color  
    )
    plt.title(f'Relationship between {x_col} and {y_col}', fontsize=14)
    plt.xlabel(x_col, fontsize=12)
    plt.ylabel(y_col, fontsize=12)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Insights
#
# (1). Deposits and Savings Behavior
#
# - Strong correlation between bank deposits and savings accounts suggests overlapping behaviors (e.g., total funds kept in the bank).
#
# - Customers who deposit regularly also tend to grow their savings balances.
#
# (2). Income, Age, and Accumulation
#
# - Age and estimated income show moderate correlations with superannuation, savings, and checking balances.
#
# - Higher earners and older individuals often accumulate larger savings, retirement funds, and may carry higher credit card or loan balances.
#
# (3). Low Correlation with Property Ownership
#
# - Property ownership depends on external factors (e.g., housing markets, inheritance, location).
#
# - These drivers are not captured by banking variables, leading to weaker correlations.
#
# (4). Business vs. Personal Banking
#
# - Business lending has a moderate relationship with bank loans, indicating some overlap between personal and business borrowing.
#
# - Its weak connection to deposits or property metrics suggests it serves a distinct customer segment or purpose.
